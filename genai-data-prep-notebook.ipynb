# %%
# !pip install biopython joblib
# Out:
# Collecting biopython
#   Downloading biopython-1.86-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (1.5.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from biopython) (2.0.2)
# Downloading biopython-1.86-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 34.6 MB/s eta 0:00:0000:0100:01
# Installing collected packages: biopython
# Successfully installed biopython-1.86

# %%
# ==============================================================================
# DATA PREP: ROBUST LOCAL PDB PROCESSING (Fixes Nested Folders)
# ==============================================================================
import os
import numpy as np
from Bio.PDB import PDBParser
from scipy.spatial.distance import pdist, squareform
from joblib import Parallel, delayed
import warnings

# --- CONFIGURATION ---
# We point to the ROOT of the dataset. The script will find the files inside.
# This path matches the standard mount point for the dataset in your screenshot.
DATASET_ROOT = "/kaggle/input/rcsb-pdb-human-macromolecular-structure-data"
OUTPUT_FILE = "protein_dataset_human_128x128.npz"

IMG_SIZE = 128
MIN_LEN = 40
MAX_LEN = 128

warnings.filterwarnings('ignore')

# --- 1. FILE FINDER (The Fix) ---
def find_all_pdb_files(root_dir):
    pdb_files = []
    print(f"📂 Scanning {root_dir} for .pdb files...")
    for root, dirs, files in os.walk(root_dir):
        for file in files:
            if file.endswith(".pdb") or file.endswith(".ent"):
                full_path = os.path.join(root, file)
                pdb_files.append(full_path)
    return pdb_files

# --- 2. PROCESSING FUNCTION ---
def process_local_pdb(file_path, img_size):
    parser = PDBParser(QUIET=True)
    try:
        # Extract ID from filename (e.g., "1a2b.pdb")
        pdb_id = os.path.basename(file_path).split('.')[0]
        
        structure = parser.get_structure(pdb_id, file_path)
        ca_coords = []
        
        # Extract CA atoms
        for model in structure:
            for chain in model:
                for residue in chain:
                    if 'CA' in residue:
                        ca_coords.append(residue['CA'].get_coord())
            break # First model only
        
        ca_coords = np.array(ca_coords)
        seq_len = len(ca_coords)
        
        # Filter size
        if seq_len < MIN_LEN or seq_len > img_size:
            return None 

        # Compute Distogram (Continuous Angstroms)
        dist_matrix = squareform(pdist(ca_coords))
        
        # Pad
        final_map = np.zeros((img_size, img_size), dtype=np.float32)
        final_map[:seq_len, :seq_len] = dist_matrix
        
        # Mask
        mask = np.zeros((img_size, img_size), dtype=np.float32)
        mask[:seq_len, :seq_len] = 1.0
        
        return (final_map, mask, pdb_id)

    except Exception:
        return None

# --- 3. EXECUTION ---
if __name__ == "__main__":
    # A. Find Files
    all_files = find_all_pdb_files(DATASET_ROOT)
    print(f"✅ Found {len(all_files)} PDB files in total.")
    
    if len(all_files) == 0:
        print("❌ CRITICAL ERROR: No PDB files found. Check if dataset is added via 'Add Data'.")
    else:
        # B. Process in Parallel
        print(f"🚀 Processing {len(all_files)} structures...")
        results = Parallel(n_jobs=-1, verbose=1)(
            delayed(process_local_pdb)(f, IMG_SIZE) for f in all_files
        )

        # C. Save
        valid_results = [r for r in results if r is not None]
        print(f"🎉 Successfully processed {len(valid_results)} valid proteins.")

        if len(valid_results) > 0:
            maps = np.array([r[0] for r in valid_results])
            masks = np.array([r[1] for r in valid_results])
            ids = np.array([r[2] for r in valid_results])
            
            np.savez_compressed(OUTPUT_FILE, contact_maps=maps, masks=masks, pdb_ids=ids)
            print(f"💾 Dataset saved to: {OUTPUT_FILE}")
            print("👉 Next Step: Create a Kaggle Dataset from this file and use it in Phase 1.")
# Out:
# 📂 Scanning /kaggle/input/rcsb-pdb-human-macromolecular-structure-data for .pdb files...
# ✅ Found 0 PDB files in total.
# ❌ CRITICAL ERROR: No PDB files found. Check if dataset is added via 'Add Data'.

# %%
# ==============================================================================
# DATA PREP: HYBRID APPROACH (Use CSV for IDs -> Download PDBs)
# ==============================================================================
# !pip install biopython joblib

import os
import pandas as pd
import numpy as np
from Bio.PDB import PDBList, PDBParser
from scipy.spatial.distance import pdist, squareform
from joblib import Parallel, delayed
import warnings

# --- CONFIGURATION ---
# Path to the CSV file in the dataset you added
CSV_PATH = "/kaggle/input/datasets/samiraalipour/rcsb-pdb-macromolecular-structure-dataset/RCSB_PDB_Macromolecular_Structure_Dataset.csv"
OUTPUT_FILE = "protein_dataset_human_128x128.npz"
TEMP_DOWNLOAD_DIR = "./pdb_downloads" # Temporary folder for downloads

IMG_SIZE = 128
MIN_LEN = 40
MAX_LEN = 128

os.makedirs(TEMP_DOWNLOAD_DIR, exist_ok=True)
warnings.filterwarnings('ignore')

# --- 1. GET VALID IDs FROM CSV ---
def get_clean_ids_from_csv(csv_path):
    print(f"📄 Reading metadata from {csv_path}...")
    try:
        df = pd.read_csv(csv_path)
        # The column is usually 'structureId' or 'pdb_id'
        if 'structureId' in df.columns:
            ids = df['structureId'].unique().tolist()
        elif 'pdb_id' in df.columns:
            ids = df['pdb_id'].unique().tolist()
        else:
            # Fallback: look for any 4-letter column
            print("⚠️ 'structureId' column not found. Searching...")
            ids = df.iloc[:, 0].unique().tolist() # Assume first col is ID
            
        print(f"✅ Found {len(ids)} high-quality human proteins in CSV.")
        return ids
    except Exception as e:
        print(f"❌ Error reading CSV: {e}")
        return []

# --- 2. DOWNLOAD & PROCESS WORKER ---
def download_and_process(pdb_id, save_dir, img_size):
    pdbl = PDBList(verbose=False)
    parser = PDBParser(QUIET=True)
    
    try:
        # A. Download
        f_path = pdbl.retrieve_pdb_file(pdb_id, pdir=save_dir, file_format="pdb")
        if not os.path.exists(f_path): return None

        # B. Parse
        structure = parser.get_structure(pdb_id, f_path)
        ca_coords = []
        for model in structure:
            for chain in model:
                for residue in chain:
                    if 'CA' in residue:
                        ca_coords.append(residue['CA'].get_coord())
            break # First model only
        
        ca_coords = np.array(ca_coords)
        seq_len = len(ca_coords)
        
        # C. SMART CROPPING (The Fix)
        # If too small, discard.
        if seq_len < MIN_LEN:
            if os.path.exists(f_path): os.remove(f_path)
            return None
            
        # If too big, cut it into 128-sized chunks!
        # This turns 1 big protein into MULTIPLE training samples.
        samples = []
        
        # Stride = 64 (50% overlap) to get more data
        stride = 64 
        
        num_crops = 0
        if seq_len > img_size:
            for start in range(0, seq_len - img_size + 1, stride):
                crop = ca_coords[start : start + img_size]
                samples.append(crop)
                num_crops += 1
                # Limit to 5 crops per protein to prevent bias
                if num_crops >= 5: break 
        else:
            # If it fits perfectly or is smaller than 128 but > 40
            samples.append(ca_coords)

        # D. Process All Crops
        processed_data = []
        for coords in samples:
            # Distance Matrix
            dist_matrix = squareform(pdist(coords))
            curr_len = len(coords)
            
            # Pad
            final_map = np.zeros((img_size, img_size), dtype=np.float32)
            final_map[:curr_len, :curr_len] = dist_matrix
            
            # Mask
            mask = np.zeros((img_size, img_size), dtype=np.float32)
            mask[:curr_len, :curr_len] = 1.0
            
            processed_data.append((final_map, mask))

        # Clean up file
        if os.path.exists(f_path): os.remove(f_path)
        
        # Return list of samples (not just one)
        return (processed_data, pdb_id)

    except Exception:
        return None
        
# --- 3. EXECUTION ---
if __name__ == "__main__":
    pdb_ids = get_clean_ids_from_csv(CSV_PATH)
    
    if len(pdb_ids) > 0:
        print(f"🚀 Starting processing of {len(pdb_ids)} proteins with SLIDING WINDOW...")
        
        results = Parallel(n_jobs=-1, verbose=1)(
            delayed(download_and_process)(pid, TEMP_DOWNLOAD_DIR, IMG_SIZE) for pid in pdb_ids
        )

        # Flatten the results (since one protein can now give multiple samples)
        all_maps = []
        all_masks = []
        all_ids = []
        
        for r in results:
            if r is not None:
                samples, pid = r
                for (m, mask) in samples:
                    all_maps.append(m)
                    all_masks.append(mask)
                    all_ids.append(pid)
        
        print(f"🎉 Successfully extracted {len(all_maps)} training samples!")

        if len(all_maps) > 0:
            # Convert to arrays
            # Caution: large lists can be slow to convert. Do it carefully.
            maps_arr = np.array(all_maps, dtype=np.float32)
            masks_arr = np.array(all_masks, dtype=np.float32)
            ids_arr = np.array(all_ids)
            
            np.savez_compressed(OUTPUT_FILE, contact_maps=maps_arr, masks=masks_arr, pdb_ids=ids_arr)
            print(f"💾 Dataset saved to: {OUTPUT_FILE}")
        else:
            print("❌ Still no data. Check internet connection?")
# Out:
# Requirement already satisfied: biopython in /usr/local/lib/python3.12/dist-packages (1.86)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (1.5.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from biopython) (2.0.2)
# 📄 Reading metadata from /kaggle/input/datasets/samiraalipour/rcsb-pdb-macromolecular-structure-dataset/RCSB_PDB_Macromolecular_Structure_Dataset.csv...
# ⚠️ 'structureId' column not found. Searching...
# ✅ Found 11832 high-quality human proteins in CSV.
# 🚀 Starting processing of 11832 proteins with SLIDING WINDOW...
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    5.9s
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:   21.0s
# [Parallel(n_jobs=-1)]: Done 442 tasks      | elapsed:   48.0s
# [Parallel(n_jobs=-1)]: Done 792 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 1242 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 1792 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 2442 tasks      | elapsed:  4.4min
# [Parallel(n_jobs=-1)]: Done 3192 tasks      | elapsed:  5.7min
# [Parallel(n_jobs=-1)]: Done 4042 tasks      | elapsed:  7.4min
# [Parallel(n_jobs=-1)]: Done 4992 tasks      | elapsed:  9.2min
# [Parallel(n_jobs=-1)]: Done 6042 tasks      | elapsed: 11.2min
# [Parallel(n_jobs=-1)]: Done 7192 tasks      | elapsed: 13.3min
# [Parallel(n_jobs=-1)]: Done 8442 tasks      | elapsed: 15.7min
# [Parallel(n_jobs=-1)]: Done 9792 tasks      | elapsed: 18.3min
# Desired structure not found or download failed. '9eu8': HTTP Error 404: Not Found
# Desired structure not found or download failed. '9euc': HTTP Error 404: Not Found
# Desired structure not found or download failed. '9bfy': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7a6w': HTTP Error 404: Not Found
# Desired structure not found or download failed. '9f9m': HTTP Error 404: Not Found
# Desired structure not found or download failed. '8c12': HTTP Error 404: Not Found
# Desired structure not found or download failed. '8q7g': HTTP Error 404: Not Found
# Desired structure not found or download failed. '6tjj': HTTP Error 404: Not Found
# Desired structure not found or download failed. '6tjk': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7qsi': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7orq': HTTP Error 404: Not Found
# Desired structure not found or download failed. '9flc': HTTP Error 404: Not Found
# Desired structure not found or download failed. '8bzz': HTTP Error 404: Not Found
# Desired structure not found or download failed. '8qfk': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7ywt': HTTP Error 404: Not Found
# Desired structure not found or download failed. '6tn2': HTTP Error 404: Not Found
# Desired structure not found or download failed. '6ytp': HTTP Error 404: Not Found
# Desired structure not found or download failed. '6yv3': HTTP Error 404: Not Found
# Desired structure not found or download failed. '8cdx': HTTP Error 404: Not Found
# Desired structure not found or download failed. '6q38': HTTP Error 404: Not Found
# Desired structure not found or download failed. '8awk': HTTP Error 404: Not Found
# Desired structure not found or download failed. '8rnd': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7q8h': HTTP Error 404: Not Found
# Desired structure not found or download failed. '9fa3': HTTP Error 404: Not Found
# Desired structure not found or download failed. '9fal': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7q8o': HTTP Error 404: Not Found
# Desired structure not found or download failed. '8cms': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7q8l': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7qns': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7q8m': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7qbh': HTTP Error 404: Not Found
# Desired structure not found or download failed. '8v3n': HTTP Error 404: Not Found
# Desired structure not found or download failed. '8vxf': HTTP Error 404: Not Found
# Desired structure not found or download failed. '6v41': HTTP Error 404: Not Found
# Desired structure not found or download failed. '6tur': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7sfd': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7zx1': HTTP Error 404: Not Found
# Desired structure not found or download failed. '8atb': HTTP Error 404: Not Found
# Desired structure not found or download failed. '8br7': HTTP Error 404: Not Found
# Desired structure not found or download failed. '8rx3': HTTP Error 404: Not Found
# Desired structure not found or download failed. '8vl9': HTTP Error 404: Not Found
# Desired structure not found or download failed. '9exx': HTTP Error 404: Not Found
# Desired structure not found or download failed. '8rxr': HTTP Error 404: Not Found
# Desired structure not found or download failed. '6zfn': HTTP Error 404: Not Found
# Desired structure not found or download failed. '6t29': HTTP Error 404: Not Found
# Desired structure not found or download failed. '9bhs': HTTP Error 404: Not Found
# Desired structure not found or download failed. '6tg4': HTTP Error 404: Not Found
# Desired structure not found or download failed. '6tkp': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7nzd': HTTP Error 404: Not Found
# Desired structure not found or download failed. '6yjs': HTTP Error 404: Not Found
# Desired structure not found or download failed. '8fj6': HTTP Error 404: Not Found
# Desired structure not found or download failed. '6sh2': HTTP Error 404: Not Found
# Desired structure not found or download failed. '8atl': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7o6x': HTTP Error 404: Not Found
# Desired structure not found or download failed. '6tlu': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7ai1': HTTP Error 404: Not Found
# Desired structure not found or download failed. '8ym7': HTTP Error 404: Not Found
# Desired structure not found or download failed. '9epv': HTTP Error 404: Not Found
# Desired structure not found or download failed. '9c1r': HTTP Error 404: Not Found
# Desired structure not found or download failed. '8oo4': HTTP Error 404: Not Found
# Desired structure not found or download failed. '6z83': HTTP Error 404: Not Found
# Desired structure not found or download failed. '8oo3': HTTP Error 404: Not Found
# Desired structure not found or download failed. '8vew': HTTP Error 404: Not Found
# Desired structure not found or download failed. '9ay7': HTTP Error 404: Not Found
# Desired structure not found or download failed. '8vey': HTTP Error 404: Not Found
# Desired structure not found or download failed. '6wew': HTTP Error 404: Not Found
# Desired structure not found or download failed. '6wet': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7p2z': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7z9u': HTTP Error 404: Not Found
# Desired structure not found or download failed. '6t8w': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7q6h': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7quk': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7qxt': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7qyl': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7r0y': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7z9s': HTTP Error 404: Not Found
# Desired structure not found or download failed. '8rij': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7nmz': HTTP Error 404: Not Found
# Desired structure not found or download failed. '9bkn': HTTP Error 404: Not Found
# Desired structure not found or download failed. '8zu2': HTTP Error 404: Not Found
# Desired structure not found or download failed. '8zul': HTTP Error 404: Not Found
# Desired structure not found or download failed. '6yb4': HTTP Error 404: Not Found
# Desired structure not found or download failed. '8vq4': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7gsb': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7gst': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7gsy': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7gt7': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7gta': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7gte': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7gth': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7gtk': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7gto': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7bf2': HTTP Error 404: Not Found
# Desired structure not found or download failed. '8eqe': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7ozf': HTTP Error 404: Not Found
# Desired structure not found or download failed. '9esa': HTTP Error 404: Not Found
# Desired structure not found or download failed. '8s07': HTTP Error 404: Not Found
# Desired structure not found or download failed. '8s01': HTTP Error 404: Not Found
# Desired structure not found or download failed. '8s06': HTTP Error 404: Not Found
# Desired structure not found or download failed. '8s0p': HTTP Error 404: Not Found
# [Parallel(n_jobs=-1)]: Done 11242 tasks      | elapsed: 21.0min
# Desired structure not found or download failed. '9eu9': HTTP Error 404: Not Found
# Desired structure not found or download failed. '9eud': HTTP Error 404: Not Found
# Desired structure not found or download failed. '9bg1': HTTP Error 404: Not Found
# Desired structure not found or download failed. '9ey4': HTTP Error 404: Not Found
# Desired structure not found or download failed. '9f9a': HTTP Error 404: Not Found
# Desired structure not found or download failed. '9bc4': HTTP Error 404: Not Found
# Desired structure not found or download failed. '8bjx': HTTP Error 404: Not Found
# Desired structure not found or download failed. '5lvs': HTTP Error 404: Not Found
# Desired structure not found or download failed. '8d35': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7nh6': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7qse': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7qnv': HTTP Error 404: Not Found
# Desired structure not found or download failed. '9flt': HTTP Error 404: Not Found
# Desired structure not found or download failed. '6xwz': HTTP Error 404: Not Found
# Desired structure not found or download failed. '6hzx': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7r1x': HTTP Error 404: Not Found
# Desired structure not found or download failed. '6tn0': HTTP Error 404: Not Found
# Desired structure not found or download failed. '6yut': HTTP Error 404: Not Found
# Desired structure not found or download failed. '9flq': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7zl6': HTTP Error 404: Not Found
# Desired structure not found or download failed. '8cdz': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7plf': HTTP Error 404: Not Found
# Desired structure not found or download failed. '9f9z': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7onp': HTTP Error 404: Not Found
# Desired structure not found or download failed. '8awr': HTTP Error 404: Not Found
# Desired structure not found or download failed. '9fa6': HTTP Error 404: Not Found
# Desired structure not found or download failed. '9fay': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7qob': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7q8q': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7nb1': HTTP Error 404: Not Found
# Desired structure not found or download failed. '6xy7': HTTP Error 404: Not Found
# Desired structure not found or download failed. '8pdj': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7q8k': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7nb2': HTTP Error 404: Not Found
# Desired structure not found or download failed. '8xn7': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7q8p': HTTP Error 404: Not Found
# Desired structure not found or download failed. '8w3x': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7pus': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7zus': HTTP Error 404: Not Found
# Desired structure not found or download failed. '8xlq': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7zx0': HTTP Error 404: Not Found
# Desired structure not found or download failed. '6yjv': HTTP Error 404: Not Found
# Desired structure not found or download failed. '6yjr': HTTP Error 404: Not Found
# Desired structure not found or download failed. '8be3': HTTP Error 404: Not Found
# Desired structure not found or download failed. '8c3d': HTTP Error 404: Not Found
# Desired structure not found or download failed. '8vhl': HTTP Error 404: Not Found
# Desired structure not found or download failed. '9bhr': HTTP Error 404: Not Found
# Desired structure not found or download failed. '6zfa': HTTP Error 404: Not Found
# Desired structure not found or download failed. '6tkq': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7qhw': HTTP Error 404: Not Found
# Desired structure not found or download failed. '6yjq': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7om1': HTTP Error 404: Not Found
# Desired structure not found or download failed. '8vw4': HTTP Error 404: Not Found
# Desired structure not found or download failed. '6ws0': HTTP Error 404: Not Found
# Desired structure not found or download failed. '9epw': HTTP Error 404: Not Found
# Desired structure not found or download failed. '6azw': HTTP Error 404: Not Found
# Desired structure not found or download failed. '9epz': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7gsv': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7px5': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7r5x': HTTP Error 404: Not Found
# Desired structure not found or download failed. '8vet': HTTP Error 404: Not Found
# Desired structure not found or download failed. '6yum': HTTP Error 404: Not Found
# Desired structure not found or download failed. '6wev': HTTP Error 404: Not Found
# Desired structure not found or download failed. '6qsw': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7z9n': HTTP Error 404: Not Found
# Desired structure not found or download failed. '9ezg': HTTP Error 404: Not Found
# Desired structure not found or download failed. '6yd3': HTTP Error 404: Not Found
# Desired structure not found or download failed. '6t8u': HTTP Error 404: Not Found
# Desired structure not found or download failed. '8g5e': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7ppx': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7qwo': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7qyk': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7qzz': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7z9i': HTTP Error 404: Not Found
# Desired structure not found or download failed. '6rav': HTTP Error 404: Not Found
# Desired structure not found or download failed. '6wfj': HTTP Error 404: Not Found
# Desired structure not found or download failed. '8be4': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7p32': HTTP Error 404: Not Found
# Desired structure not found or download failed. '9fyf': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7pi4': HTTP Error 404: Not Found
# Desired structure not found or download failed. '8vq3': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7gsl': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7gsw': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7gt0': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7gt3': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7gt6': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7gtm': HTTP Error 404: Not Found
# Desired structure not found or download failed. '8rzy': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7q5t': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7ozd': HTTP Error 404: Not Found
# Desired structure not found or download failed. '8bn8': HTTP Error 404: Not Found
# Desired structure not found or download failed. '8gdt': HTTP Error 404: Not Found
# Desired structure not found or download failed. '8s0h': HTTP Error 404: Not Found
# Desired structure not found or download failed. '8s0k': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7td9': HTTP Error 404: Not Found
# Desired structure not found or download failed. '8xz7': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7bf1': HTTP Error 404: Not Found
# Desired structure not found or download failed. '8yhf': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7q5w': HTTP Error 404: Not Found
# Desired structure not found or download failed. '7pa3': HTTP Error 404: Not Found
# [Parallel(n_jobs=-1)]: Done 11832 out of 11832 | elapsed: 22.1min finished
# 🎉 Successfully extracted 43179 training samples!
# 💾 Dataset saved to: protein_dataset_human_128x128.npz
